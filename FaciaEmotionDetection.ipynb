# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatofficial33/facialexpressiondetector/blob/main/FaciaEmotionDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Install required libraries
# !pip install kaggle tensorflow keras opencv-python-headless matplotlib seaborn scikit-learn

# %%
# !unzip fer2013.zip -d /content/unzipped

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Dense, Flatten,
                                      Dropout, BatchNormalization, GlobalAveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report, confusion_matrix

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Verify the uploaded & unzipped dataset structure
base_dir = '/content/unzipped'

print("Contents of /content/unzipped:")
for item in os.listdir(base_dir):
    print(f"  {item}/")
    sub = os.path.join(base_dir, item)
    if os.path.isdir(sub):
        for sub_item in os.listdir(sub):
            count = len(os.listdir(os.path.join(sub, sub_item)))
            print(f"    {sub_item}/  ({count} images)")
# Out:
# Contents of /content/unzipped:
#   train/
#     surprise/  (3171 images)
#     angry/  (3995 images)
#     disgust/  (436 images)
#     fear/  (4097 images)
#     sad/  (4830 images)
#     neutral/  (4965 images)
#     happy/  (7215 images)
#   test/
#     surprise/  (831 images)
#     angry/  (958 images)
#     disgust/  (111 images)
#     fear/  (1024 images)
#     sad/  (1247 images)
#     neutral/  (1233 images)
#     happy/  (1774 images)

# %%
# ── OPTION A: if your folder has train/ and test/ subfolders ──────────────────
train_dir = '/content/unzipped/train'
test_dir  = '/content/unzipped/test'

# ── OPTION B: if all emotion folders are directly inside unzipped ─────────────
# (comment out Option A above and uncomment below)
# from sklearn.model_selection import train_test_split
# train_dir = '/content/unzipped'
# test_dir  = '/content/unzipped'

# Confirm paths exist
print("Train dir exists:", os.path.exists(train_dir))
print("Test dir exists: ", os.path.exists(test_dir))
print("\nEmotion classes found in train:")
print(sorted(os.listdir(train_dir)))
# Out:
# Train dir exists: True
# Test dir exists:  True
#
# Emotion classes found in train:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
emotion_labels = sorted(os.listdir(train_dir))
print(f"Detected emotion classes: {emotion_labels}")

# Count images per class
print("\n=== Dataset Summary ===")
train_counts = {}
test_counts  = {}

for emotion in emotion_labels:
    tp = os.path.join(train_dir, emotion)
    vp = os.path.join(test_dir,  emotion)
    train_counts[emotion] = len(os.listdir(tp)) if os.path.isdir(tp) else 0
    test_counts[emotion]  = len(os.listdir(vp)) if os.path.isdir(vp) else 0
    print(f"{emotion:10s} -> Train: {train_counts[emotion]:5d} | Test: {test_counts[emotion]:4d}")

print(f"\nTotal Train: {sum(train_counts.values())} | Total Test: {sum(test_counts.values())}")

# Class distribution plot
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
colors = ['#E74C3C','#E67E22','#F1C40F','#2ECC71','#3498DB','#9B59B6','#1ABC9C']

axes[0].bar(train_counts.keys(), train_counts.values(), color=colors)
axes[0].set_title('Training Set Distribution', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Emotion')
axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', rotation=45)

axes[1].bar(test_counts.keys(), test_counts.values(), color=colors, alpha=0.8)
axes[1].set_title('Test Set Distribution', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Emotion')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('/content/class_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# Sample images
fig, axes = plt.subplots(2, len(emotion_labels), figsize=(16, 5))
for i, emotion in enumerate(emotion_labels):
    path = os.path.join(train_dir, emotion)
    imgs = os.listdir(path)
    for row in range(2):
        img = cv2.imread(os.path.join(path, imgs[row]), cv2.IMREAD_GRAYSCALE)
        axes[row, i].imshow(img, cmap='gray')
        axes[row, i].set_title(emotion, fontsize=9, fontweight='bold')
        axes[row, i].axis('off')

plt.suptitle('Sample Images Per Emotion Class', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Detected emotion classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
#
# === Dataset Summary ===
# angry      -> Train:  3995 | Test:  958
# disgust    -> Train:   436 | Test:  111
# fear       -> Train:  4097 | Test: 1024
# happy      -> Train:  7215 | Test: 1774
# neutral    -> Train:  4965 | Test: 1233
# sad        -> Train:  4830 | Test: 1247
# surprise   -> Train:  3171 | Test:  831
#
# Total Train: 28709 | Total Test: 7178

# %%
IMG_SIZE   = 48
BATCH_SIZE = 64
NUM_CLASSES = len(emotion_labels)

train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Class mapping: {train_generator.class_indices}")
print(f"Num classes detected: {train_generator.num_classes}")
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Class mapping: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Num classes detected: 7

# %%
def build_emotion_cnn(input_shape=(48, 48, 1), num_classes=7):
    model = Sequential([

        # Block 1
        Conv2D(64, (3,3), padding='same', activation='relu',
               input_shape=input_shape, kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Conv2D(64, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        # Block 2
        Conv2D(128, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Conv2D(128, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.25),

        # Block 3
        Conv2D(256, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Conv2D(256, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.30),

        # Block 4
        Conv2D(512, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Conv2D(512, (3,3), padding='same', activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        MaxPooling2D(2,2),
        Dropout(0.30),

        # Classification head
        GlobalAveragePooling2D(),
        Dense(512, activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Dropout(0.50),
        Dense(256, activation='relu', kernel_regularizer=l2(1e-4)),
        BatchNormalization(),
        Dropout(0.40),
        Dense(num_classes, activation='softmax')
    ])
    return model

model = build_emotion_cnn(input_shape=(IMG_SIZE, IMG_SIZE, 1), num_classes=NUM_CLASSES)
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,090,759 (19.42 MB)
#  Trainable params: 5,085,383 (19.40 MB)
#  Non-trainable params: 5,376 (21.00 KB)

# %%
EPOCHS = 60

checkpoint = ModelCheckpoint(
    '/content/best_emotion_model.h5',
    monitor='val_accuracy', save_best_only=True, mode='max', verbose=1
)
early_stop = EarlyStopping(
    monitor='val_accuracy', patience=15, restore_best_weights=True, verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1
)

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator,
    callbacks=[checkpoint, early_stop, reduce_lr],
    verbose=1
)

print(f"\nBest val accuracy: {max(history.history['val_accuracy']):.4f}")
# Out:
# Epoch 1/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.1858 - loss: 2.6412
# Epoch 1: val_accuracy improved from None to 0.24714, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 90s 134ms/step - accuracy: 0.1998 - loss: 2.4215 - val_accuracy: 0.2471 - val_loss: 2.1046 - learning_rate: 0.0010
# Epoch 2/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2336 - loss: 2.1441
# Epoch 2: val_accuracy improved from 0.24714 to 0.28685, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.2570 - loss: 2.0836 - val_accuracy: 0.2868 - val_loss: 1.9614 - learning_rate: 0.0010
# Epoch 3/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3547 - loss: 1.8690
# Epoch 3: val_accuracy improved from 0.28685 to 0.44177, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.3894 - loss: 1.7887 - val_accuracy: 0.4418 - val_loss: 1.6495 - learning_rate: 0.0010
# Epoch 4/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4575 - loss: 1.6310
# Epoch 4: val_accuracy improved from 0.44177 to 0.49624, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.4696 - loss: 1.5973 - val_accuracy: 0.4962 - val_loss: 1.5223 - learning_rate: 0.0010
# Epoch 5/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5093 - loss: 1.5186
# Epoch 5: val_accuracy improved from 0.49624 to 0.52424, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 70ms/step - accuracy: 0.5184 - loss: 1.4976 - val_accuracy: 0.5242 - val_loss: 1.4933 - learning_rate: 0.0010
# Epoch 6/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5421 - loss: 1.4390
# Epoch 6: val_accuracy improved from 0.52424 to 0.54179, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.5409 - loss: 1.4354 - val_accuracy: 0.5418 - val_loss: 1.4283 - learning_rate: 0.0010
# Epoch 7/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5693 - loss: 1.3877
# Epoch 7: val_accuracy improved from 0.54179 to 0.57509, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.5627 - loss: 1.3972 - val_accuracy: 0.5751 - val_loss: 1.3515 - learning_rate: 0.0010
# Epoch 8/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5670 - loss: 1.3868
# Epoch 8: val_accuracy did not improve from 0.57509
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.5708 - loss: 1.3769 - val_accuracy: 0.5734 - val_loss: 1.3537 - learning_rate: 0.0010
# Epoch 9/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5827 - loss: 1.3621
# Epoch 9: val_accuracy did not improve from 0.57509
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 70ms/step - accuracy: 0.5787 - loss: 1.3669 - val_accuracy: 0.5635 - val_loss: 1.4020 - learning_rate: 0.0010
# Epoch 10/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5910 - loss: 1.3505
# Epoch 10: val_accuracy improved from 0.57509 to 0.59794, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.5857 - loss: 1.3581 - val_accuracy: 0.5979 - val_loss: 1.3463 - learning_rate: 0.0010
# Epoch 11/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5946 - loss: 1.3516
# Epoch 11: val_accuracy did not improve from 0.59794
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 70ms/step - accuracy: 0.5929 - loss: 1.3519 - val_accuracy: 0.5687 - val_loss: 1.4060 - learning_rate: 0.0010
# Epoch 12/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5929 - loss: 1.3493
# Epoch 12: val_accuracy did not improve from 0.59794
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.5952 - loss: 1.3476 - val_accuracy: 0.5977 - val_loss: 1.3502 - learning_rate: 0.0010
# Epoch 13/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6046 - loss: 1.3431
# Epoch 13: val_accuracy did not improve from 0.59794
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.6022 - loss: 1.3519 - val_accuracy: 0.5474 - val_loss: 1.4662 - learning_rate: 0.0010
# Epoch 14/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6067 - loss: 1.3394
# Epoch 14: val_accuracy did not improve from 0.59794
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6052 - loss: 1.3501 - val_accuracy: 0.5761 - val_loss: 1.4262 - learning_rate: 0.0010
# Epoch 15/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6066 - loss: 1.3503
# Epoch 15: val_accuracy improved from 0.59794 to 0.61062, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6047 - loss: 1.3549 - val_accuracy: 0.6106 - val_loss: 1.3270 - learning_rate: 0.0010
# Epoch 16/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6075 - loss: 1.3590
# Epoch 16: val_accuracy did not improve from 0.61062
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 70ms/step - accuracy: 0.6093 - loss: 1.3581 - val_accuracy: 0.6077 - val_loss: 1.3600 - learning_rate: 0.0010
# Epoch 17/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6155 - loss: 1.3330
# Epoch 17: val_accuracy did not improve from 0.61062
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6111 - loss: 1.3490 - val_accuracy: 0.6077 - val_loss: 1.3628 - learning_rate: 0.0010
# Epoch 18/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6207 - loss: 1.3376
# Epoch 18: val_accuracy did not improve from 0.61062
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 72ms/step - accuracy: 0.6165 - loss: 1.3487 - val_accuracy: 0.5832 - val_loss: 1.4235 - learning_rate: 0.0010
# Epoch 19/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6177 - loss: 1.3541
# Epoch 19: val_accuracy did not improve from 0.61062
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6181 - loss: 1.3503 - val_accuracy: 0.6021 - val_loss: 1.3727 - learning_rate: 0.0010
# Epoch 20/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6223 - loss: 1.3393
# Epoch 20: val_accuracy did not improve from 0.61062
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6230 - loss: 1.3443 - val_accuracy: 0.6027 - val_loss: 1.3724 - learning_rate: 0.0010
# Epoch 21/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6426 - loss: 1.2786
# Epoch 21: val_accuracy improved from 0.61062 to 0.62301, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 70ms/step - accuracy: 0.6420 - loss: 1.2724 - val_accuracy: 0.6230 - val_loss: 1.2899 - learning_rate: 5.0000e-04
# Epoch 22/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6520 - loss: 1.2339
# Epoch 22: val_accuracy improved from 0.62301 to 0.64739, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6505 - loss: 1.2328 - val_accuracy: 0.6474 - val_loss: 1.2491 - learning_rate: 5.0000e-04
# Epoch 23/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6553 - loss: 1.2141
# Epoch 23: val_accuracy did not improve from 0.64739
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6551 - loss: 1.2150 - val_accuracy: 0.6443 - val_loss: 1.2371 - learning_rate: 5.0000e-04
# Epoch 24/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6657 - loss: 1.1868
# Epoch 24: val_accuracy did not improve from 0.64739
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 70ms/step - accuracy: 0.6615 - loss: 1.1961 - val_accuracy: 0.6415 - val_loss: 1.2298 - learning_rate: 5.0000e-04
# Epoch 25/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6640 - loss: 1.1846
# Epoch 25: val_accuracy improved from 0.64739 to 0.65171, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.6638 - loss: 1.1834 - val_accuracy: 0.6517 - val_loss: 1.2095 - learning_rate: 5.0000e-04
# Epoch 26/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6690 - loss: 1.1694
# Epoch 26: val_accuracy did not improve from 0.65171
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.6648 - loss: 1.1790 - val_accuracy: 0.6500 - val_loss: 1.2069 - learning_rate: 5.0000e-04
# Epoch 27/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6668 - loss: 1.1653
# Epoch 27: val_accuracy did not improve from 0.65171
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.6675 - loss: 1.1717 - val_accuracy: 0.6493 - val_loss: 1.2280 - learning_rate: 5.0000e-04
# Epoch 28/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6759 - loss: 1.1438
# Epoch 28: val_accuracy did not improve from 0.65171
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.6690 - loss: 1.1584 - val_accuracy: 0.6417 - val_loss: 1.2259 - learning_rate: 5.0000e-04
# Epoch 29/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6760 - loss: 1.1506
# Epoch 29: val_accuracy improved from 0.65171 to 0.65673, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 29: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6736 - loss: 1.1537 - val_accuracy: 0.6567 - val_loss: 1.2055 - learning_rate: 5.0000e-04
# Epoch 30/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6799 - loss: 1.1414
# Epoch 30: val_accuracy did not improve from 0.65673
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.6765 - loss: 1.1466 - val_accuracy: 0.6510 - val_loss: 1.2038 - learning_rate: 5.0000e-04
# Epoch 31/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6788 - loss: 1.1322
# Epoch 31: val_accuracy did not improve from 0.65673
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.6756 - loss: 1.1442 - val_accuracy: 0.6484 - val_loss: 1.2275 - learning_rate: 5.0000e-04
# Epoch 32/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6878 - loss: 1.1264
# Epoch 32: val_accuracy improved from 0.65673 to 0.65784, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.6801 - loss: 1.1419 - val_accuracy: 0.6578 - val_loss: 1.2107 - learning_rate: 5.0000e-04
# Epoch 33/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6837 - loss: 1.1307
# Epoch 33: val_accuracy did not improve from 0.65784
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.6790 - loss: 1.1378 - val_accuracy: 0.6425 - val_loss: 1.2473 - learning_rate: 5.0000e-04
# Epoch 34/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6887 - loss: 1.1149
# Epoch 34: val_accuracy did not improve from 0.65784
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.6851 - loss: 1.1290 - val_accuracy: 0.6569 - val_loss: 1.1962 - learning_rate: 5.0000e-04
# Epoch 35/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6937 - loss: 1.1101
# Epoch 35: val_accuracy did not improve from 0.65784
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.6872 - loss: 1.1255 - val_accuracy: 0.6500 - val_loss: 1.2185 - learning_rate: 5.0000e-04
# Epoch 36/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6915 - loss: 1.1156
# Epoch 36: val_accuracy did not improve from 0.65784
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.6875 - loss: 1.1187 - val_accuracy: 0.6410 - val_loss: 1.2506 - learning_rate: 5.0000e-04
# Epoch 37/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6940 - loss: 1.1109
# Epoch 37: val_accuracy did not improve from 0.65784
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.6910 - loss: 1.1214 - val_accuracy: 0.6559 - val_loss: 1.2005 - learning_rate: 5.0000e-04
# Epoch 38/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6935 - loss: 1.1152
# Epoch 38: val_accuracy improved from 0.65784 to 0.66578, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 38: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 74ms/step - accuracy: 0.6921 - loss: 1.1177 - val_accuracy: 0.6658 - val_loss: 1.1951 - learning_rate: 5.0000e-04
# Epoch 39/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6992 - loss: 1.1004
# Epoch 39: val_accuracy did not improve from 0.66578
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.6954 - loss: 1.1103 - val_accuracy: 0.6598 - val_loss: 1.2156 - learning_rate: 5.0000e-04
# Epoch 40/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6940 - loss: 1.1075
# Epoch 40: val_accuracy improved from 0.66578 to 0.67038, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 40: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.6909 - loss: 1.1169 - val_accuracy: 0.6704 - val_loss: 1.1820 - learning_rate: 5.0000e-04
# Epoch 41/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7058 - loss: 1.0869
# Epoch 41: val_accuracy did not improve from 0.67038
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.6981 - loss: 1.1017 - val_accuracy: 0.6519 - val_loss: 1.2369 - learning_rate: 5.0000e-04
# Epoch 42/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7038 - loss: 1.0954
# Epoch 42: val_accuracy improved from 0.67038 to 0.67303, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 42: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 74ms/step - accuracy: 0.6979 - loss: 1.1113 - val_accuracy: 0.6730 - val_loss: 1.1929 - learning_rate: 5.0000e-04
# Epoch 43/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7101 - loss: 1.0709
# Epoch 43: val_accuracy did not improve from 0.67303
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.7002 - loss: 1.0981 - val_accuracy: 0.6566 - val_loss: 1.2370 - learning_rate: 5.0000e-04
# Epoch 44/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6986 - loss: 1.1118
# Epoch 44: val_accuracy did not improve from 0.67303
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 70ms/step - accuracy: 0.6975 - loss: 1.1109 - val_accuracy: 0.6615 - val_loss: 1.2287 - learning_rate: 5.0000e-04
# Epoch 45/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7071 - loss: 1.0863
# Epoch 45: val_accuracy did not improve from 0.67303
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.7027 - loss: 1.0994 - val_accuracy: 0.6524 - val_loss: 1.2498 - learning_rate: 5.0000e-04
# Epoch 46/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7153 - loss: 1.0633
# Epoch 46: val_accuracy did not improve from 0.67303
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.7196 - loss: 1.0515 - val_accuracy: 0.6630 - val_loss: 1.2313 - learning_rate: 2.5000e-04
# Epoch 47/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7346 - loss: 1.0105
# Epoch 47: val_accuracy improved from 0.67303 to 0.68041, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 47: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.7304 - loss: 1.0201 - val_accuracy: 0.6804 - val_loss: 1.1588 - learning_rate: 2.5000e-04
# Epoch 48/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7305 - loss: 1.0122
# Epoch 48: val_accuracy improved from 0.68041 to 0.68376, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 48: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.7322 - loss: 1.0052 - val_accuracy: 0.6838 - val_loss: 1.1672 - learning_rate: 2.5000e-04
# Epoch 49/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7413 - loss: 0.9789
# Epoch 49: val_accuracy did not improve from 0.68376
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.7340 - loss: 0.9943 - val_accuracy: 0.6768 - val_loss: 1.1737 - learning_rate: 2.5000e-04
# Epoch 50/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7407 - loss: 0.9851
# Epoch 50: val_accuracy did not improve from 0.68376
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.7400 - loss: 0.9825 - val_accuracy: 0.6793 - val_loss: 1.1689 - learning_rate: 2.5000e-04
# Epoch 51/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7389 - loss: 0.9739
# Epoch 51: val_accuracy did not improve from 0.68376
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.7370 - loss: 0.9822 - val_accuracy: 0.6780 - val_loss: 1.1732 - learning_rate: 2.5000e-04
# Epoch 52/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7411 - loss: 0.9717
# Epoch 52: val_accuracy did not improve from 0.68376
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 70ms/step - accuracy: 0.7396 - loss: 0.9702 - val_accuracy: 0.6709 - val_loss: 1.1854 - learning_rate: 2.5000e-04
# Epoch 53/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7531 - loss: 0.9347
# Epoch 53: val_accuracy improved from 0.68376 to 0.68849, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 53: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 68ms/step - accuracy: 0.7518 - loss: 0.9340 - val_accuracy: 0.6885 - val_loss: 1.1632 - learning_rate: 1.2500e-04
# Epoch 54/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7630 - loss: 0.9125
# Epoch 54: val_accuracy did not improve from 0.68849
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 73ms/step - accuracy: 0.7605 - loss: 0.9138 - val_accuracy: 0.6857 - val_loss: 1.1638 - learning_rate: 1.2500e-04
# Epoch 55/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7630 - loss: 0.9108
# Epoch 55: val_accuracy improved from 0.68849 to 0.68905, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 55: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.7621 - loss: 0.9088 - val_accuracy: 0.6890 - val_loss: 1.1686 - learning_rate: 1.2500e-04
# Epoch 56/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7628 - loss: 0.9038
# Epoch 56: val_accuracy improved from 0.68905 to 0.69003, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 56: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.7638 - loss: 0.8998 - val_accuracy: 0.6900 - val_loss: 1.1573 - learning_rate: 1.2500e-04
# Epoch 57/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7718 - loss: 0.8800
# Epoch 57: val_accuracy did not improve from 0.69003
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.7692 - loss: 0.8898 - val_accuracy: 0.6838 - val_loss: 1.1734 - learning_rate: 1.2500e-04
# Epoch 58/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7682 - loss: 0.8814
# Epoch 58: val_accuracy did not improve from 0.69003
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 69ms/step - accuracy: 0.7688 - loss: 0.8794 - val_accuracy: 0.6878 - val_loss: 1.1504 - learning_rate: 1.2500e-04
# Epoch 59/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7752 - loss: 0.8643
# Epoch 59: val_accuracy improved from 0.69003 to 0.69253, saving model to /content/best_emotion_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 59: finished saving model to /content/best_emotion_model.h5
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.7724 - loss: 0.8730 - val_accuracy: 0.6925 - val_loss: 1.1505 - learning_rate: 1.2500e-04
# Epoch 60/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7789 - loss: 0.8599
# Epoch 60: val_accuracy did not improve from 0.69253
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 32s 71ms/step - accuracy: 0.7728 - loss: 0.8659 - val_accuracy: 0.6890 - val_loss: 1.1716 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 59.
#
# Best val accuracy: 0.6925

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['accuracy'],     label='Train', color='#3498DB', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Val',   color='#E74C3C', linewidth=2)
axes[0].set_title('Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Accuracy')
axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['loss'],     label='Train', color='#3498DB', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Val',   color='#E74C3C', linewidth=2)
axes[1].set_title('Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Loss')
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('/content/training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Test Accuracy: {test_acc*100:.2f}%")

test_generator.reset()
y_pred = np.argmax(model.predict(test_generator, verbose=1), axis=1)
y_true = test_generator.classes

print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=emotion_labels))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=emotion_labels, yticklabels=emotion_labels, linewidths=0.5)
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.ylabel('True Label'); plt.xlabel('Predicted Label')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('/content/confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Test Accuracy: 69.25%
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#        angry       0.63      0.64      0.63       958
#      disgust       0.81      0.60      0.69       111
#         fear       0.56      0.47      0.51      1024
#        happy       0.89      0.89      0.89      1774
#      neutral       0.61      0.71      0.65      1233
#          sad       0.58      0.54      0.56      1247
#     surprise       0.78      0.84      0.81       831
#
#     accuracy                           0.69      7178
#    macro avg       0.69      0.67      0.68      7178
# weighted avg       0.69      0.69      0.69      7178

# %%
import json

model.save('/content/emotion_detection_model.h5')

label_map = {str(v): k for k, v in train_generator.class_indices.items()}
with open('/content/emotion_labels.json', 'w') as f:
    json.dump(label_map, f, indent=2)

print("Model saved.")
print(f"Label map: {label_map}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved.
# Label map: {'0': 'angry', '1': 'disgust', '2': 'fear', '3': 'happy', '4': 'neutral', '5': 'sad', '6': 'surprise'}

# %%
import tensorflow as tf
import numpy as np
import cv2, base64, json, io
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
from PIL import Image

# Load model and labels
model      = tf.keras.models.load_model('/content/emotion_detection_model.h5')
with open('/content/emotion_labels.json') as f:
    label_map = json.load(f)
emotion_labels_ordered = [label_map[str(i)] for i in range(len(label_map))]

EMOTION_EMOJI = {
    'angry':'😠','disgust':'🤢','fear':'😨',
    'happy':'😄','neutral':'😐','sad':'😢','surprise':'😲'
}
EMOTION_COLOR = {
    'angry':'#E74C3C','disgust':'#8E44AD','fear':'#2C3E50',
    'happy':'#F1C40F','neutral':'#7F8C8D','sad':'#3498DB','surprise':'#E67E22'
}

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

def preprocess_face(face_img):
    face = cv2.resize(face_img, (48, 48))
    if len(face.shape) == 3:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
    face = face.astype('float32') / 255.0
    return np.expand_dims(np.expand_dims(face, -1), 0)

def detect_emotion_from_frame(frame_array):
    img_bgr  = cv2.cvtColor(frame_array, cv2.COLOR_RGB2BGR)
    img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    faces    = face_cascade.detectMultiScale(img_gray, 1.1, 5, minSize=(30,30))
    annotated = img_bgr.copy()
    result    = {'faces_found': len(faces), 'emotions': []}

    if len(faces) == 0:
        cv2.putText(annotated, 'No face detected', (20,50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,0,255), 2)
        return cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB), result

    for (x, y, w, h) in faces:
        pad  = int(0.1 * w)
        x1,y1 = max(0,x-pad), max(0,y-pad)
        x2,y2 = min(img_bgr.shape[1],x+w+pad), min(img_bgr.shape[0],y+h+pad)

        preds        = model.predict(preprocess_face(img_gray[y1:y2, x1:x2]), verbose=0)[0]
        emotion_name = emotion_labels_ordered[np.argmax(preds)]
        confidence   = float(np.max(preds)) * 100

        result['emotions'].append({
            'emotion': emotion_name, 'confidence': confidence,
            'all_scores': {emotion_labels_ordered[i]: float(preds[i])*100
                           for i in range(len(emotion_labels_ordered))}
        })

        c = tuple(int(EMOTION_COLOR[emotion_name].lstrip('#')[i:i+2],16) for i in (4,2,0))
        cv2.rectangle(annotated, (x1,y1), (x2,y2), c, 3)
        label = f"{emotion_name.upper()} {confidence:.1f}%"
        (lw,lh),_ = cv2.getTextSize(label, cv2.FONT_HERSHEY_DUPLEX, 0.8, 2)
        cv2.rectangle(annotated, (x1,y1-lh-14), (x1+lw+8,y1), c, -1)
        cv2.putText(annotated, label, (x1+4,y1-6),
                    cv2.FONT_HERSHEY_DUPLEX, 0.8, (255,255,255), 2)

    return cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB), result

# Webcam JS — opens camera, waits for single button click
WEBCAM_JS = """
async function captureWebcam() {
    const video  = document.createElement('video');
    const canvas = document.createElement('canvas');
    const div    = document.createElement('div');
    const btn    = document.createElement('button');
    const status = document.createElement('p');

    div.style.cssText    = `font-family:sans-serif;text-align:center;padding:16px;
                             background:#1a1a2e;border-radius:12px;max-width:600px;margin:0 auto;`;
    video.style.cssText  = `border-radius:8px;width:100%;max-width:560px;
                             border:2px solid #4ecdc4;display:block;margin:0 auto 12px;`;
    btn.style.cssText    = `background:#4ecdc4;color:#1a1a2e;border:none;
                             padding:12px 32px;font-size:16px;font-weight:bold;
                             border-radius:8px;cursor:pointer;margin:8px;`;
    status.style.cssText = `color:#ccc;font-size:14px;margin:8px 0;`;

    btn.innerText    = '📷  Capture & Detect Emotion';
    status.innerText = 'Camera loading...';
    div.appendChild(status);
    div.appendChild(video);
    div.appendChild(btn);
    document.body.appendChild(div);

    const stream = await navigator.mediaDevices.getUserMedia({ video: true });
    video.srcObject = stream;
    await video.play();
    status.innerText = '✅ Camera ready — press the button when ready!';

    return new Promise(resolve => {
        btn.onclick = () => {
            canvas.width  = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getTracks().forEach(t => t.stop());
            video.srcObject  = null;
            status.innerText = '⏳ Detecting emotion...';
            btn.disabled     = true;
            resolve(canvas.toDataURL('image/jpeg', 0.95));
        };
    });
}
captureWebcam();
"""

# ── Run ───────────────────────────────────────────────────────────────────────
print("="*55)
print("   FACIAL EMOTION DETECTION — ONE-SHOT WEBCAM CAPTURE")
print("="*55)
print("\nAllow camera access when prompted, then click Capture.\n")

img_data_url = eval_js(WEBCAM_JS)
img_bytes    = b64decode(img_data_url.split(',')[1])
frame_array  = np.array(Image.open(io.BytesIO(img_bytes)).convert('RGB'))

print(f"Frame captured: {frame_array.shape[1]}x{frame_array.shape[0]}px")
print("Running detection...\n")

annotated_frame, result = detect_emotion_from_frame(frame_array)

# ── Display result ────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.patch.set_facecolor('#1a1a2e')

axes[0].imshow(annotated_frame)
axes[0].set_title('Detected Emotion', color='white', fontsize=14, fontweight='bold', pad=10)
axes[0].axis('off')
axes[0].set_facecolor('#252540')

if result['faces_found'] > 0:
    top    = result['emotions'][0]
    scores = top['all_scores']
    colors = [EMOTION_COLOR.get(e, '#888') for e in scores]

    bars = axes[1].barh(list(scores.keys()), list(scores.values()),
                         color=colors, edgecolor='none', height=0.6)
    axes[1].set_xlim(0, 100)
    axes[1].set_xlabel('Confidence (%)', color='white', fontsize=11)
    axes[1].set_title('Prediction Confidence', color='white', fontsize=14,
                       fontweight='bold', pad=10)
    axes[1].tick_params(colors='white')
    axes[1].set_facecolor('#252540')
    for spine in axes[1].spines.values():
        spine.set_edgecolor('#444')
    for bar, score in zip(bars, scores.values()):
        axes[1].text(score+1, bar.get_y()+bar.get_height()/2,
                     f'{score:.1f}%', va='center', color='white',
                     fontsize=10, fontweight='bold')

    detected   = top['emotion']
    confidence = top['confidence']
    emoji      = EMOTION_EMOJI.get(detected, '')
    fig.suptitle(f'{emoji}  Detected: {detected.upper()}  ({confidence:.1f}% confidence)',
                 color='white', fontsize=16, fontweight='bold', y=1.02)

    print("="*50)
    print(f"  RESULT: {emoji} {detected.upper()} ({confidence:.1f}%)")
    print("="*50)
    print("\nAll scores:")
    for emo, score in sorted(scores.items(), key=lambda x: -x[1]):
        print(f"  {emo:10s}: {score:5.1f}%  {'█'*int(score/5)}")
else:
    axes[1].text(0.5, 0.5, 'No face\ndetected', ha='center', va='center',
                 color='white', fontsize=16, transform=axes[1].transAxes)
    axes[1].set_facecolor('#252540')
    axes[1].axis('off')
    print("\n⚠️  No face detected. Try better lighting and face the camera directly.")

axes[0].set_facecolor('#252540')
plt.tight_layout()
plt.savefig('/content/emotion_result.png', dpi=150, bbox_inches='tight', facecolor='#1a1a2e')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# =======================================================
#    FACIAL EMOTION DETECTION — ONE-SHOT WEBCAM CAPTURE
# =======================================================
#
# Allow camera access when prompted, then click Capture.
#
# Frame captured: 640x480px
# Running detection...
#
# ==================================================
#   RESULT: 😐 NEUTRAL (86.2%)
# ==================================================
#
# All scores:
#   neutral   :  86.2%  █████████████████
#   sad       :   7.7%  █
#   angry     :   4.5%
#   fear      :   1.4%
#   happy     :   0.3%
#   surprise  :   0.0%
#   disgust   :   0.0%
